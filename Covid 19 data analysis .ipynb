# %% [markdown]
# # COVID-19 DATA ANALYSIS

# %% [markdown]
# # Importing the modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importing Covid-19 Dataset

# %%
df=pd.read_csv("full_grouped.csv")
print(df)
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %% [markdown]
# # Lets look at the data

# %%
df.head()
df
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
# ...

# %% [markdown]
# # Now we can check the statistical information of data

# %%
df.describe(include='all')
# Out:
#               Date Country/Region     Confirmed         Deaths     Recovered  \
# count        35156          35156  3.515600e+04   35156.000000  3.515600e+04
# unique         188            187           NaN            NaN           NaN
# top     2020-01-22    Afghanistan           NaN            NaN           NaN
# freq           187            188           NaN            NaN           NaN
# mean           NaN            NaN  2.356663e+04    1234.068239  1.104813e+04
# std            NaN            NaN  1.499818e+05    7437.238354  6.454640e+04
# min            NaN            NaN  0.000000e+00       0.000000  0.000000e+00
# 25%            NaN            NaN  1.000000e+00       0.000000  0.000000e+00
# 50%            NaN            NaN  2.500000e+02       4.000000  3.300000e+01
# 75%            NaN            NaN  3.640250e+03      78.250000  1.286250e+03
# max            NaN            NaN  4.290259e+06  148011.000000  1.846641e+06
#
# ...

# %% [markdown]
# # Column information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35156 entries, 0 to 35155
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            35156 non-null  object
#  1   Country/Region  35156 non-null  object
#  2   Confirmed       35156 non-null  int64
#  3   Deaths          35156 non-null  int64
#  4   Recovered       35156 non-null  int64
#  5   Active          35156 non-null  int64
#  6   New cases       35156 non-null  int64
#  7   New deaths      35156 non-null  int64
#  8   New recovered   35156 non-null  int64
#  9   WHO Region      35156 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 2.7+ MB

# %% [markdown]
# # Now we can check if there is any missing values

# %%
df.isnull().sum()
# Out:
# Date              0
# Country/Region    0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# New cases         0
# New deaths        0
# New recovered     0
# WHO Region        0
# dtype: int64

# %% [markdown]
# # Now we can check if there is any duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Viewing Column names

# %%
df.columns
# Out:
# Index(['Date', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Data types of our columns

# %%
df.dtypes
# Out:
# Date              object
# Country/Region    object
# Confirmed          int64
# Deaths             int64
# Recovered          int64
# Active             int64
# New cases          int64
# New deaths         int64
# New recovered      int64
# WHO Region        object
# dtype: object

# %% [markdown]
# # Check Correlations

# %%
#Drop Columns for Correlations as Country/Region and WHO Region as it's datatype is Object

# %%
df.drop(['WHO Region'],axis=1,inplace=True)

# %%
df.drop(['Date'],axis=1,inplace=True)

# %%
df.drop(['Country/Region'],axis=1,inplace=True)

# %%
df.corr()
# Out:
#                Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed       1.000000  0.912016   0.894418  0.949940   0.893966
# Deaths          0.912016  1.000000   0.761093  0.891647   0.767812
# Recovered       0.894418  0.761093   1.000000  0.710665   0.808816
# Active          0.949940  0.891647   0.710665  1.000000   0.846513
# New cases       0.893966  0.767812   0.808816  0.846513   1.000000
# New deaths      0.602815  0.630283   0.515154  0.583212   0.733583
# New recovered   0.675623  0.551870   0.761926  0.534027   0.725761
#
#                New deaths  New recovered
# Confirmed        0.602815       0.675623
# Deaths           0.630283       0.551870
# Recovered        0.515154       0.761926
# Active           0.583212       0.534027
# New cases        0.733583       0.725761
# New deaths       1.000000       0.503319
# New recovered    0.503319       1.000000

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap = 'coolwarm',center=0)
plt.title("CORRELATION HEATMAP")
plt.show()

# %% [markdown]
# # New Cases

# %%
 abs(df.corr())[['New cases']].style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_35f04_row0_col0 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_35f04_row1_col0 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_35f04_row2_col0 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_35f04_row3_col0 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_35f04_row4_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_35f04_row5_col0 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_35f04_row6_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_35f04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35f04_level0_col0" class="col_heading level0 col0" >New cases</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35f04_level0_row0" class="row_heading level0 row0" >Confirmed</th>
#       <td id="T_35f04_row0_col0" class="data row0 col0" >0.893966</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Count Plot for WHO Regions

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='WHO Region',data=df)
plt.title("WHO REGIONS")
plt.show()

# %% [markdown]
# # Total number of Confirmed, Deaths, Recovered and Active cases around the world

# %%
plt.figure(figsize=(8,2))
total_count = ['Confirmed', 'Deaths', 'Recovered', 'Active']
column_sums = df[total_count].sum().plot(kind='bar')
plt.xlabel("Status")
plt.ylabel("Count In Millions")
plt.title("Count of Population Status")
# Out:
# Text(0.5, 1.0, 'Count of Population Status')

# %% [markdown]
# # New Deaths and New Recovered Cases

# %%
sns.boxplot(df['New deaths'])
plt.title('New Deaths')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(df['New recovered'])
plt.title('New Recovered')
# Out:
# Text(0.5, 1.0, 'New Recovered')

# %% [markdown]
# # Total Recovered and Active cases on the basis of WHO Region

# %%
Region = df.groupby(by='WHO Region').sum()

# %%
Region['Recovered'].plot(kind='pie',  figsize=(8,5), shadow=True, autopct='%0.1f%%') 
plt.title(' Recovered')
# Out:
# Text(0.5, 1.0, ' Recovered')

# %%
Region['Active'].plot(kind='pie', figsize=(8,5), shadow=True, autopct='%0.1f%%') 
plt.title(' Active')
# Out:
# Text(0.5, 1.0, ' Active')
